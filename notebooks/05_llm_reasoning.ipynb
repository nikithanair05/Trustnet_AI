# %%
from openai import OpenAI

# %%
query = "Pay onboarding fee to secure interview slot"

# %%
prompt = f"""
Profile Analysis:

Query:
{query}

Retrieved Scam Patterns:
{results['documents'][0]}

Explain why this profile may be suspicious.
"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       4 Query:
#       5 {query}
#       6
#       7 Retrieved Scam Patterns:
# ----> 8 {results['documents'][0]}
#       9
#      10 Explain why this profile may be suspicious.
#      11 """
#
# NameError: name 'results' is not defined
